# %%
# %cd /content/drive/MyDrive/Python
# Out:
# /content/drive/MyDrive/Python

# %% [markdown]
# Single Line

# %%
message = "Hi there, How are you !"
print(message)
# Out:
# Hi there, How are you !

# %%
message = "Hi there', How are you !"
print(message)
# Out:
# Hi there', How are you !

# %% [markdown]
# Mutiple Line

# %%
message_multi = """A paragraph is a self-contained unit of discourse in writing dealing with a particular point or idea.
A paragraph consists of one or more sentences.
Though not required by the syntax of any language, paragraphs are usually an expected part of formal writing, used to organize longer prose."""
print(message_multi)
# Out:
# A paragraph is a self-contained unit of discourse in writing dealing with a particular point or idea.
# A paragraph consists of one or more sentences.
# Though not required by the syntax of any language, paragraphs are usually an expected part of formal writing, used to organize longer prose.

# %% [markdown]
# Length count

# %%
print(len(message))
# Out:
# 24

# %% [markdown]
# Grab letter

# %%
print(message[7])
# Out:
# e

# %%
print(message[0:8])
# Out:
# Hi there

# %%
print(message[:8])
# Out:
# Hi there

# %%
print(message[11:])
# Out:
# How are you !

# %% [markdown]
# Capital & Small letter

# %%
capital = message.upper()
small = message.lower()
print(capital)
print(small)
# Out:
# HI THERE', HOW ARE YOU !
# hi there', how are you !

# %% [markdown]
# **count** anything
#
# ```
# # This is formatted as code
# ```

# %%
print(message.count('How'))
# Out:
# 1

# %%
print(message.count('H'))
# Out:
# 2

# %% [markdown]
# **find** anything

# %%
print(message.find('are'))
# Out:
# 15

# %%
print(message.find('H'))
# Out:
# 0

# %% [markdown]
# **replace** anything

# %%
replace = message.replace('How','Who')
print(replace)
# Out:
# Hi there', Who are you !

# %% [markdown]
# Combine text

# %%
First = "Shahriar"
Last = "Shakil"
my_name = First + ' ' + Last
print(my_name)
# Out:
# Shahriar Shakil

# %%
name_my = "{} {}".format(Last,First)
print(name_my)
# Out:
# Shakil Shahriar

# %%
name = f"{First.upper()} {Last.upper()}"
print(name)
# Out:
# SHAHRIAR SHAKIL

# %%
print(dir(First))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
