# %%
# %cd /content/drive/MyDrive/Python
# Out:
# /content/drive/MyDrive/Python

# %% [markdown]
# List

# %%
courses = ['history ','math','physics','ict']
print(courses)
# Out:
# ['history ', 'math', 'physics', 'ict']

# %%
print(len(courses))
# Out:
# 4

# %%
print(courses[3])
# Out:
# ict

# %%
print(courses[-2])
# Out:
# physics

# %%
print(courses[:2])
# Out:
# ['history ', 'math']

# %%
print(courses[1:])
# Out:
# ['math', 'physics', 'ict']

# %% [markdown]
# add element

# %%
courses.append('bangla')
print(courses)
# Out:
# ['history ', 'math', 'physics', 'ict', 'bangla']

# %%
courses.insert(0,'english')
print(courses)
# Out:
# ['english', 'history ', 'math', 'physics', 'ict', 'bangla']

# %%
print(courses)
# Out:
# ['english', 'history ', 'math', 'physics', 'ict', 'bangla']

# %%
couses2 = ['art','chemistry']

# %%
courses.extend(couses2)
print(courses)
# Out:
# ['english', 'history ', 'math', 'physics', 'ict', 'bangla', 'art', 'chemistry']

# %% [markdown]
# remove item

# %%
courses.remove('english')
print(courses)
# Out:
# ['history ', 'math', 'physics', 'ict', 'bangla', 'art', 'chemistry']

# %%
pooped = courses.pop()
print(pooped)
print(courses)
# Out:
# chemistry
# ['history ', 'math', 'physics', 'ict', 'bangla', 'art']

# %% [markdown]
# sorting item

# %%
#reverse
courses.reverse()
print(courses)
# print(reverse)
# Out:
# ['art', 'bangla', 'ict', 'physics', 'math', 'history ']

# %%
#sort
courses.sort()
print(courses)
# Out:
# ['art', 'bangla', 'history ', 'ict', 'math', 'physics']

# %%
num = ['4','2','0','7','1']
num.sort()
print(num)
# Out:
# ['0', '1', '2', '4', '7']

# %%
num = ['4','2','0','7','1']
num.sort(reverse=True)
print(num)
# Out:
# ['7', '4', '2', '1', '0']

# %%
sorted1 = sorted(courses)
sorted2 = sorted(num)
print(sorted1)
print(sorted2)
# Out:
# ['art', 'bangla', 'history ', 'ict', 'math', 'physics']
# ['0', '1', '2', '4', '7']

# %%
print(min(num))
print(max(num))
# Out:
# 0
# 7

# %%
print(courses.index('ict'))
# Out:
# 3

# %%
print('Science' in courses)
# Out:
# False

# %%
print('ict' in courses)
# Out:
# True

# %%
for item in courses:
  print(item)
# Out:
# art
# bangla
# history
# ict
# math
# physics

# %%
for index,item in enumerate(courses):
  print(index, item)
  # print(item)
# Out:
# 0 art
# 1 bangla
# 2 history
# 3 ict
# 4 math
# 5 physics

# %%
for index,item in enumerate(courses, start = 2):
  print(index, item)
  # print(item)
# Out:
# 2 art
# 3 bangla
# 4 history
# 5 ict
# 6 math
# 7 physics

# %%
cour_str = ', '.join(courses)
print(cour_str)
# Out:
# art, bangla, history , ict, math, physics

# %%
cour_str = ' * '.join(courses)
print(cour_str)
# Out:
# art * bangla * history  * ict * math * physics

# %%
new_list = cour_str.split(' * ')
print(new_list)
# Out:
# ['art', 'bangla', 'history ', 'ict', 'math', 'physics']

# %% [markdown]
# **touple**

# %%
courses_t = ('history ','math','physics','ict')
print(courses_t)
# Out:
# ('history ', 'math', 'physics', 'ict')

# %% [markdown]
# **set**

# %%
courses_s = {'history ','math','physics','ict'}
print(courses_s)
# Out:
# {'history ', 'physics', 'ict', 'math'}

# %%
courses_s = {'history ','math','physics','ict', 'ict'}
print(courses_s)
# Out:
# {'history ', 'physics', 'ict', 'math'}
