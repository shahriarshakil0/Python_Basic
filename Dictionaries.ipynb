# %%
# %cd /content/drive/MyDrive/Python
# Out:
# /content/drive/MyDrive/Python

# %%
student = {'name': ['shahriar','shakil'], 'id': ['8558','8559'], 'age': [22,23]}
print(student)
# Out:
# {'name': ['shahriar', 'shakil'], 'id': ['8558', '8559'], 'age': [22, 23]}

# %%
print(student['name'])
# Out:
# ['shahriar', 'shakil']

# %%
print(student.get('phone','Not Found'))
# Out:
# Not Found

# %% [markdown]
# **add element**

# %%
student['courses'] = ['bangla','english']
print(student)
# Out:
# {'name': ['shahriar', 'shakil'], 'id': ['8558', '8559'], 'age': [22, 23], 'courses': ['bangla', 'english']}

# %%
student.update({'name':'sharmin','id': '714','age':21})
print(student)
# Out:
# {'name': 'sharmin', 'id': '714', 'age': 21, 'courses': ['bangla', 'english']}

# %% [markdown]
# **remove element**

# %%
del student['age']
print(student)
# Out:
# {'name': 'sharmin', 'id': '714', 'courses': ['bangla', 'english']}

# %%
courses = student.pop('courses')
print(courses)
print(student)
# Out:
# ['bangla', 'english']
# {'name': 'sharmin', 'id': '714'}

# %%
print(len(student))
# Out:
# 2

# %%
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name', 'id'])
# dict_values(['sharmin', '714'])
# dict_items([('name', 'sharmin'), ('id', '714')])

# %%
student1 = {'name': ['shahriar','shakil'], 'id': ['8558','8559'], 'age': [22,23]}
print(student1)
# Out:
# {'name': ['shahriar', 'shakil'], 'id': ['8558', '8559'], 'age': [22, 23]}

# %%
for key,value in student1.items():
  print(key,value)
# Out:
# name ['shahriar', 'shakil']
# id ['8558', '8559']
# age [22, 23]
